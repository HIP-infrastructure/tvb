# %% [markdown]
# # Welcome to the TVB HIP app
#
# This is the Virtual Brain (TVB) HIP app, which provides access to the TVB simulation tools, as well as integrations with the wider EBRAINS ecosystem.
#
# ## Next steps
#
# Please look through the following links depending on your needs.
#
# - Reconstruction: building a virtual brain model from raw data
# - Simulation: run simulations of brain model
# - Inference: compute model parameters from functional data
# - EBRAINS integrations
#   - KG & Atlas services: receive data from EBRAINS sources
#   - HPC services: run computationally intensive models on HPC resources
# - WP1 Showcase 2

# %% [markdown]
# # Included tools
#
# The following sections present a quick tour of the tools in the TVB app.
#
# ## Python environment
#
# The Python and Jupyter environment provide most

# %%
import sys
print(sys.executable)
# !python -V
# !pip -V
# Out:
# /usr/bin/python
# Python 3.10.12
# pip 22.0.2 from /usr/lib/python3/dist-packages/pip (python 3.10)

# %% [markdown]
# ## TVB libraries
#
# Core TVB libraries are provided for performing simulations and inference of parameters.

# %%
import tvb, vbjax
import torch, sbi, tvb_inversion

# %% [markdown]
# ## EBRAINS interop
#
# Interoperability with the wider EBRAINS ecosystem is providing with the Siibra package for interacting with the KG & atlas services, and PyUnicore for sending jobs to the high performance computing services.

# %%
import siibra
import pyunicore
# Out:
# [siibra:INFO] Version: 0.4a63
# [siibra:WARNING] This is a development release. Use at your own risk.
# [siibra:INFO] Please file bugs and issues at https://github.com/FZJ-INM1-BDA/siibra-python.

# %% [markdown]
# ## Command line tools
#
# the TVB app includes tools from FreeSurfer & FSL for MRI analysis, Mtrix3 for tractography, along with compilers for building other tools as required, such as high performance simulation codes.

# %%
# !which recon-all
# !which flirt
# !which mrconvert
# !which make
# !which g++
# Out:
# /usr/local/freesurfer/7.4.1/bin/recon-all
# /usr/local/fsl/bin/flirt
# /usr/bin/mrconvert
# /usr/bin/make
# /usr/bin/g++
